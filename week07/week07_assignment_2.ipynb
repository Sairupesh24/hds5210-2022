# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# In the cell below, create a function called **parse_banner(url)** that takes as it's one parameter the URL of the webpage to be parsed for links.  Make sure you include docstrings and a good test case using hte URL provided above.

# %%
from bs4 import BeautifulSoup
import requests

# Note that you'll need to fetch the data using the following syntax to include headers
url = 'https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency'

headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'html.parser')
# that make the web server think you're a real web browser.

# %%
response.status_code
# Out:
# 200

# %%
def parse_banner(url):
    results = []
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    div = soup.find_all('div', {"class":"col-md-8"})[0]
    for hospital_list in div.find_all('ul'):
        state = hospital_list.previous_sibling.previous_sibling.string
        for hospital in hospital_list.find_all('li'):
            print(hospital.text, state)
            results.append([hospital.text, state])
    return results

# %%
import doctest
doctest.run_docstring_examples(parse_banner, globals(), verbose=True)
# Out:
# Finding tests in NoName

# %%
banner = parse_banner('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency')
assert len(banner)==38, 'Length of result should have been 38, but {} returned.'.format(len(banner))
assert banner[0][1]=='Arizona', 'Wrong data found in the first result item: {}'.format(banner[0])
# Out:
# Banner - University Medical Center Phoenix Arizona
# Banner - University Medical Center South  Arizona
# Banner - University Medical Center Tucson Arizona
# Banner Baywood Medical Center  Arizona
# Banner Behavioral Health Hospital Arizona
# Banner Boswell Medical Center Arizona
# Banner Casa Grande Medical Center Arizona
# Banner Del E. Webb Medical Center Arizona
# Banner Desert Medical Center/Cardon Children's Medical Center   Arizona
# Banner Estrella Medical Center Arizona
# Banner Gateway Medical Center/Banner MD Anderson Cancer Center Arizona
# Banner Goldfield Medical Center   Arizona
# Banner Heart Hospital Arizona
# Banner Ironwood Medical Center Arizona
# Banner Ocotillo Medical Center Arizona
# Banner Payson Medical Center Arizona
# Banner Rehabilitation Hospitals Arizona
# Banner Thunderbird Medical Center Arizona
# Page Hospital Arizona
# Banner Lassen Medical Center California
# Banner Fort Collins Medical Center Colorado
# McKee Medical Center Colorado
# North Colorado Medical Center Colorado
# Sterling Regional Medical Center Colorado
# East Morgan County Hospital Colorado
# Ogallala Community Hospital Nebraska
# Banner Churchill Community Hospital Nevada
# Banner Wyoming Medical Center Central Campus Wyoming
# Banner Wyoming Medical Center East Campus Wyoming
# Community Hospital Wyoming
# Washakie Medical Center Wyoming
# Platte County Memorial Hospital Wyoming
# Arizona State-Specific Regulations
# California State-Specific Regulations
# Colorado State-Specific Regulations
# Nebraska State-Specific Regulations
# Nevada State-Specific Regulations
# Wyoming State-Specific Regulations

# %% [markdown]
# ---
#
# ## 33.2 Using a REST API (from GitHub.com)
#
# Many websites provide something called a REST API to access information from their site programatically, rather than relying on HTML.  One example is GitHub.com, whose API allows you do to things like "list all the public repositories for a user."
#
# The documentation for GitHub.com's REST API can be found here: https://docs.github.com/en/rest/guides/getting-started-with-the-rest-api
#
# Create a function called **repo_summary(user)** that takes a GitHub.com user name as it's parameter and retrieves a list of all the repositories you can see for that user.  The specific documentation for the this kind of request can be found here: https://docs.github.com/en/rest/reference/repos#list-repositories-for-a-user. Make sure your function is well documented with a docstring and includes a simple test to verify that you get back 12 repositories when querying for the repositories for user **paulboal**.
#
# I've provided a related example to help you out.

# %%
# Example -- this example of code shows how to get basic information on the user paulboal
# For your solution, make sure you meet the requirements in the instructions above.
import requests
import json

response = requests.get('https://api.github.com/users/paulboal')
data = response.json()

print('This information is about {}. His website is {}.'.format(data.get('login'), data.get('blog')))
# Out:
# This information is about paulboal. His website is www.amitechsolutions.com.

# %%
# Your code Here
def repo_summary(user):
    
    url = 'https://api.github.com/users/paulboal/repos'
    response = requests.get(url)
    data = response.json()
    repo_summary = []
    for repository in data:
        if repository not in repo_summary:
            repos = repo_summary.append(repository["name"])
    print(repo_summary)

# %%
repos = repo_summary('paulboal')
# Out:
# ['ajaxterm', 'cms_hospital_compare', 'collibra-scripts', 'coronadatascraper', 'hadoop-heuristicsminer', 'hds5210-2021', 'hds5210-2022', 'jupyterhub-nbgrader', 'nppes_demo', 'pexpect-curses', 'scm-products', 'tdwi-accelerate-2017-python']

# %%
import requests
def repo_summary(user):
    '''(list) -> int
    >>> len(repos)==12
    True
    '''
    link = ('https://api.github.com/users/paulboal/repos')
    api_link = requests.get(link)
    api_data = api_link.json()
    repos_Data = (api_data)
    repo_summary = [print(f"- {items['name']}") for items in repos_Data]
    return repo_summary

# %%
import doctest
doctest.run_docstring_examples(repo_summary, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     len(repos)==12
# Expecting:
#     True
# ok

# %%
repos = repo_summary('paulboal')
assert len(repos)==12, 'Expecing 12, but {} were found'.format(len(repos))
# Out:
# - ajaxterm
# - cms_hospital_compare
# - collibra-scripts
# - coronadatascraper
# - hadoop-heuristicsminer
# - hds5210-2021
# - hds5210-2022
# - jupyterhub-nbgrader
# - nppes_demo
# - pexpect-curses
# - scm-products
# - tdwi-accelerate-2017-python

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Your Code Here
import pandas as pd

tables = pd.read_html('https://www.health.harvard.edu/staying-healthy/listing_of_vitamins')

# %%
tables[0]
# Out:
#                                                     0  \
# 0                                             VITAMIN
# 1   RETINOIDS AND CAROTENE (vitamin A; includes re...
# 2                                THIAMIN (vitamin B1)
# 3                             RIBOFLAVIN (vitamin B2)
# 4                 NIACIN (vitamin B3, nicotinic acid)
# 5                       PANTOTHENIC ACID (vitamin B5)
# 6   PYRIDOXINE (vitamin B6, pyridoxal, pyridoxine,...
# 7                             COBALAMIN (vitamin B12)
# 8                                              BIOTIN
# 9                           ASCORBIC ACID (vitamin C)
# 10                                            CHOLINE
# 11                             CALCIFEROL (vitamin D)
# 12                       ALPHA-TOCOPHEROL (vitamin E)
# 13           FOLIC ACID (vitamin B9, folate, folacin)
# 14               PHYLLOQUINONE, MENADIONE (vitamin K)
# 15                                            MINERAL
# 16                                            CALCIUM
# 17                                           CHLORIDE
# 18                                           CHROMIUM
# 19                                             COPPER
# 20                                           FLUORIDE
# 21                                             IODINE
# 22                                               IRON
# 23                                          MAGNESIUM
# 24                                          MANGANESE
# 25                                         MOLYBDENUM
# 26                                         PHOSPHORUS
# 27                                          POTASSIUM
# 28                                           SELENIUM
# 29                                             SODIUM
# 30                                             SULFUR
# 31                                               ZINC
# 32   *Recommended dietary allowance **Adequate intake
#
#                                                     1  \
# 0                                            BENEFITS
# 1   Essential for vision Lycopene may lower prosta...
# 2   Helps convert food into energy. Needed for hea...
# 3   Helps convert food into energy. Needed for hea...
# 4   Helps convert food into energy. Essential for ...
# 5   Helps convert food into energy. Helps make lip...
# 6   Aids in lowering homocysteine levels and may r...
# 7   Aids in lowering homocysteine levels and may l...
# 8   Helps convert food into energy and synthesize ...
# 9   Foods rich in vitamin C may lower the risk for...
# 10  Helps make and release the neurotransmitter ac...
# 11  Helps maintain normal blood levels of calcium ...
# 12  Acts as an antioxidant, neutralizing unstable ...
# 13  Vital for new cell creationHelps prevent brain...
# 14  Activates proteins and calcium essential to bl...
# 15                                           BENEFITS
# 16  Builds and protects bones and teeth. Helps wit...
# 17  Balances fluids in the body. A component of st...
# 18  Enhances the activity of insulin, helps mainta...
# 19  Plays an important role in iron metabolism and...
# 20  Encourages strong bone formation. Keeps dental...
# 21  Part of thyroid hormone, which helps set body ...
# 22  Helps hemoglobin in red blood cells and myoglo...
# 23  Needed for many chemical reactions in the body...
# 24  Helps form bones. Helps metabolize amino acids...
# 25  Part of several enzymes, one of which helps wa...
# 26  Helps build and protect bones and teeth. Part ...
# 27  Balances fluids in the body. Helps maintain st...
# 28  Acts as an antioxidant, neutralizing unstable ...
# 29  Balances fluids in the body. Helps send nerve ...
# 30  Helps form bridges that shape and stabilize so...
# 31  Helps form many enzymes and proteins and creat...
# 32   *Recommended dietary allowance **Adequate intake
#
#                                                     2  \
# 0       RECOMMENDED AMOUNT (daily RDA* or daily AI**)
# 1   M: 900 mcg (3,000 IU)W: 700 mcg (2,333 IU)Some...
# 2                                M: 1.2 mg, W: 1.1 mg
# 3                                M: 1.3 mg, W: 1.1 mg
# 4                                  M: 16 mg, W: 14 mg
# 5                                    M: 5 mg, W: 5 mg
# 6   31–50 years old: M: 1.3 mg, W: 1.3 mg; 51+ yea...
# 7                              M: 2.4 mcg, W: 2.4 mcg
# 8                                M: 30 mcg, W: 30 mcg
# 9               M: 90 mg, W: 75 mg Smokers: Add 35 mg
# 10                               M: 550 mg, W: 425 mg
# 11        31–70: 15 mcg (600 IU) 71+: 20 mcg (800 IU)
# 12  M: 15 mg, W: 15 mg (15 mg equals about 22 IU f...
# 13                             M: 400 mcg, W: 400 mcg
# 14                              M: 120 mcg, W: 90 mcg
# 15      RECOMMENDED AMOUNT (daily RDA* or daily AI**)
# 16  31–50: M: 1,000 mg, W: 1,000 mg 51-70: M: 1,00...
# 17  14-50: M/W: 2.3 g, 51-70 M/W: 2.0 g, 71+: M/W:...
# 18  14–50: M: 35 mcg, 14-18: W: 24 mcg 19-50: W: 2...
# 19                             M: 900 mcg, W: 900 mcg
# 20                                   M: 4 mg, W: 3 mg
# 21                             M: 150 mcg, W: 150 mcg
# 22     19–50: M: 8 mg, W: 18 mg 51+: M: 8 mg, W: 8 mg
# 23                          18+: M: 420 mg, W: 320 mg
# 24                               M: 2.3 mg, W: 1.8 mg
# 25                               M: 45 mcg, W: 45 mcg
# 26                               M: 700 mg, W: 700 mg
# 27                                 M: 4.7 g, W: 4.7 g
# 28                               M: 55 mcg, W: 55 mcg
# 29                           M: 2,300 mg, W: 2,300 mg
# 30                                            Unknown
# 31                                  M: 11 mg, W: 8 mg
# 32   *Recommended dietary allowance **Adequate intake
#
#                                                     3  \
# 0                            UPPER LIMIT (UL) per day
# 1                         3,000 mcg (about 10,000 IU)
# 2                                           Not known
# 3                                           Not known
# 4                                               35 mg
# 5                                           Not known
# 6                                              100 mg
# 7                                           Not known
# 8                                           Not known
# 9                                            2,000 mg
# 10                                           3,500 mg
# 11                                  50 mcg (2,000 IU)
# 12  1,000 mg (nearly 1,500 IU natural vitamin E; 2...
# 13                                          1,000 mcg
# 14                                          Not known
# 15                           UPPER LIMIT (UL) per day
# 16                                           2,500 mg
# 17                                          Not known
# 18                                          Not known
# 19                                         10,000 mcg
# 20                                              10 mg
# 21                                          1,100 mcg
# 22                                              45 mg
# 23  350 mg (Note: This upper limit applies to supp...
# 24                                              11 mg
# 25                                          2,000 mcg
# 26                      31–70: 4,000 mg 71+: 3,000 mg
# 27                                          Not known
# 28                                            400 mcg
# 29                                     Not determined
# 30                                            Unknown
# 31                                              40 mg
# 32   *Recommended dietary allowance **Adequate intake
#
#                                                     4  \
# 0                                   GOOD FOOD SOURCES
# 1   Sources of retinoids: beef liver, eggs, shrimp...
# 2   Pork chops, brown rice, ham, soymilk, watermel...
# 3   Milk, eggs, yogurt, cheese, meats, green leafy...
# 4   Meat, poultry, fish, fortified and whole grain...
# 5   Wide variety of nutritious foods, including ch...
# 6   Meat, fish, poultry, legumes, tofu and other s...
# 7   Meat, poultry, fish, milk, cheese, eggs, forti...
# 8   Many foods, including whole grains, organ meat...
# 9   Fruits and fruit juices (especially citrus), p...
# 10  Many foods, especially milk, eggs, liver, salm...
# 11  Fortified milk or margarine, fortified cereals...
# 12  Wide variety of foods, including vegetable oil...
# 13  Fortified grains and cereals, asparagus, okra,...
# 14  Cabbage, liver, eggs, milk, spinach, broccoli,...
# 15                                  GOOD FOOD SOURCES
# 16  Yogurt, cheese, milk, tofu, sardines, salmon, ...
# 17  Salt (sodium chloride), soy sauce, processed f...
# 18  Meat, poultry, fish, eggs, potatoes, some cere...
# 19  Liver, shellfish, nuts, seeds, whole-grain pro...
# 20  Water that is fluoridated, toothpaste with flu...
# 21             Iodized salt, processed foods, seafood
# 22  Red meat, poultry, eggs, fruits, green vegetab...
# 23  Green vegetables such as spinach and broccoli,...
# 24             Fish, nuts, legumes, whole grains, tea
# 25                Legumes, nuts, grain products, milk
# 26  Wide variety of foods, including milk and dair...
# 27    Meat, milk, fruits, vegetables, grains, legumes
# 28  Organ meats, seafood, walnuts, sometimes plant...
# 29       Salt, soy sauce, processed foods, vegetables
# 30  Protein-rich foods, such as meats, fish, poult...
# 31  Red meat, poultry, oysters and some other seaf...
# 32   *Recommended dietary allowance **Adequate intake
#
#                                                     5
# 0                                       DID YOU KNOW?
# 1   Many people get too much preformed vitamin A f...
# 2            Most nutritious foods have some thiamin.
# 3         Most Americans get enough of this nutrient.
# 4   Niacin occurs naturally in food and can also b...
# 5   Deficiency causes burning feet and other neuro...
# 6      Many people don't get enough of this nutrient.
# 7   Some people, particularly older adults, are de...
# 8   Some is made by bacteria in the gastrointestin...
# 9   Evidence that vitamin C helps reduce colds has...
# 10  No rmally the body makes small amounts of chol...
# 11  Many people don't get enough of this nutrient....
# 12  Vitamin E does not prevent wrinkles or slow ot...
# 13  Many people don't get enough of this nutrient....
# 14  Intestinal bacteria make a form of vitamin K t...
# 15                                      DID YOU KNOW?
# 16  Adults absorb roughly 30% of calcium ingested,...
# 17  New recommendations (DRIs) for chloride are un...
# 18  Unrefined foods such as brewer's yeast, nuts, ...
# 19  More than half of the copper in foods is absor...
# 20          Harmful to children in excessive amounts.
# 21  To prevent iodine deficiencies, some countries...
# 22  Many women of childbearing age don't get enoug...
# 23  The majority of magnesium in the body is found...
# 24  If you take supplements or have manganese in y...
# 25                  Molybdenum deficiencies are rare.
# 26  Certain drugs bind with phosphorus, making it ...
# 27  Food sources do not cause toxicity, but high-d...
# 28  Researchers are investigating whether selenium...
# 29  While experts recommend that people limit sodi...
# 30  Sulfur is a component of thiamin and certain a...
# 31  Because vegetarians absorb less zinc, experts ...
# 32   *Recommended dietary allowance **Adequate intake

# %% [markdown]
# ---
#
# ## Check your work above
#
# If you didn't get them all correct, take a few minutes to think through those that aren't correct.
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Follow the instruction on the prompt below to either ssave and submit your work, or continue working.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %% [markdown]
# ---

# %%
a=input('''
Are you ready to submit your work?
1. Click the Save icon (or do Ctrl-S / Cmd-S)
2. Type "yes" or "no" below
3. Press Enter

''')

if a=='yes':
    # !git add week07_assignment_2.ipynb
    # !git commit -a -m "Submitting the week 7 programming exercises"
    # !git push
else:
    print('''
    
OK. We can wait.
''')
